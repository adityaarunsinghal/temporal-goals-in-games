# %%
import pandas as pd
from IPython.display import Image

# %%
setup_diff = pd.read_csv("/Users/aditya/Documents/GitHub/game_creation_research/Object Physics Sandbox/human_data/setup_difficulty_scores.csv")
setup_diff
# Out:
#     id    name game_num  difficulty
# 0    1  Ingrid   GAME_1           6
# 1    1  Ingrid   GAME_2           7
# 2    1  Ingrid   GAME_3           7
# 3    1  Ingrid   GAME_4           6
# 4    1  Ingrid   GAME_5           9
# 5    2  Chhavi   GAME_1           6
# 6    2  Chhavi   GAME_2           7
# 7    2  Chhavi   GAME_3           4
# 8    2  Chhavi   GAME_4           4
# 9    2  Chhavi   GAME_5           8
# 10   3     Nav   GAME_1           3
# 11   3     Nav   GAME_2           4
# 12   3     Nav   GAME_3           4
# 13   3     Nav   GAME_4           8
# 14   3     Nav   GAME_5           4
# 15   4     Adi   GAME_1           5
# 16   4     Adi   GAME_2           8
# 17   4     Adi   GAME_3           9
# 18   4     Adi   GAME_4           3
# 19   4     Adi   GAME_5           8

# %% [markdown]
# # Game 1
#
# ## “Shoot the ball into the bucket through the gaps in objects.
# ## Top gap gets 3 points. Middle gaps get 2 and straight into bucket is 1 point.”

# %%
Image(filename='../saved_media_important/GAME1_Setup.png')

# %% [markdown]
# # Game 2
#
# ## “Deflect the ball on box and get into bucket - no points if no deflection”

# %%
Image(filename='../saved_media_important/GAME2_Setup.png')

# %% [markdown]
# # Game 3
#
# ## “Get the ball to land on the platform to the right for one point”

# %%
Image(filename='../saved_media_important/GAME3_Setup.png')

# %% [markdown]
# # Game 4
#
# ## “Shoot the ball and touch as many objects as possible.
# ## 1 point for first object, 2 for second, 3 for third…”

# %%
Image(filename='../saved_media_important/GAME4_Setup.png')

# %% [markdown]
# # Game 5
#
# # “Get ball into bucket AFTER bouncing off all 3 walls”

# %%
Image(filename='../saved_media_important/GAME5_Setup.png')
